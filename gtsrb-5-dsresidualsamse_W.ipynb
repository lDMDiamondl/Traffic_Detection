# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import transforms
from torch.optim.optimizer import Optimizer
from PIL import Image
import os
import time
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
random.seed(42)
np.random.seed(42)
os.environ["PYTHONHASHSEED"] = str(42)
torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.cuda.manual_seed_all(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
data_dir = './data'
train_path = './data/Train'
test_path = './data'

# %%
class GTSRBDataset(Dataset):
    def __init__(self, root_dir, transform=None, is_train=True):
        self.root_dir = root_dir
        self.transform = transform
        self.is_train = is_train
        if self.is_train:
            self.samples = []
            for class_id in sorted(os.listdir(root_dir)):
                class_path = os.path.join(root_dir, class_id)
                if os.path.isdir(class_path):
                    for img_name in sorted(os.listdir(class_path)):
                        if img_name.endswith('.png'):
                            self.samples.append((os.path.join(class_path, img_name), int(class_id)))
        else:
            self.csv_data = pd.read_csv(os.path.join(root_dir, 'Test.csv'))
    def __len__(self):
        return len(self.samples) if self.is_train else len(self.csv_data)
    def __getitem__(self, idx):
        if self.is_train:
            img_path, label = self.samples[idx]
        else:
            row = self.csv_data.iloc[idx]
            img_path = os.path.join(self.root_dir, row['Path'])
            label = int(row['ClassId'])
        image = Image.open(img_path).convert('RGB')
        if self.transform: image = self.transform(image)
        return image, label

# %%
def print_parameters(model, model_name, verbose=True):
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    if verbose:
        print(f"\n{'='*20} [{model_name} Layer Details] {'='*20}")
        print(f"{'Layer Name':<40} | {'Shape':<25} | {'Parameters':<15}")
        print("-" * 85)
        for name, param in model.named_parameters():
            if param.requires_grad:
                num = param.numel()
                shape_str = str(list(param.shape))
                print(f"{name:<40} | {shape_str:<25} | {num:>15,}")
        print("-" * 85)
        print(f"{'TOTAL TRAINABLE PARAMETERS':<68} | {total_params:>15,}")
        print('='*85)
    return total_params

# %%
def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs, model_name):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    history = {'loss': [], 'accuracy': [], 'val_loss': [], 'val_accuracy': [], 'time': []}
    best_val_acc = 0.0
    
    for epoch in range(num_epochs):
        epoch_start = time.time()
        model.train()
        train_loss, train_correct, train_total = 0, 0, 0
        
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            # First Forward
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.first_step()
            
            # Second Forward
            optimizer.zero_grad()
            criterion(model(images), labels).backward()
            optimizer.second_step()
            
            train_loss += loss.item()
            _, predicted = outputs.max(1)
            train_total += labels.size(0)
            train_correct += predicted.eq(labels).sum().item()
            
        model.eval()
        val_loss, val_correct, val_total = 0, 0, 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                val_loss += criterion(outputs, labels).item()
                _, predicted = outputs.max(1)
                val_total += labels.size(0)
                val_correct += predicted.eq(labels).sum().item()
        
        curr_val_acc = val_correct / val_total
        history['loss'].append(train_loss/len(train_loader))
        history['accuracy'].append(train_correct/train_total)
        history['val_loss'].append(val_loss/len(test_loader))
        history['val_accuracy'].append(curr_val_acc)
        history['time'].append(time.time() - epoch_start)
        
        print(f"Epoch {epoch+1} | Loss: {history['loss'][-1]:.4f} | Acc: {history['accuracy'][-1]*100:.2f}% | Val Acc: {curr_val_acc*100:.2f}%")
        if curr_val_acc > best_val_acc:
            best_val_acc = curr_val_acc
            torch.save(model.state_dict(), f'best_{model_name}.pth')
            
    return history

# %%
def evaluate_model(model, test_loader, model_name):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    correct = 0
    total = 0
    print(f"--- Evaluating {model_name} ---")
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    final_acc = 100 * correct / total
    print(f"Total Images: {total}")
    print(f"Correct: {correct}")
    print(f"Accuracy: {final_acc:.2f}%\n")
    return final_acc

# %%
class SAM(Optimizer):
    def __init__(self, params, base_optimizer, rho=0.05, **kwargs):
        params = list(params)
        defaults = dict(rho=rho, **kwargs)
        super().__init__(params, defaults)
        self.base_optimizer = base_optimizer(params, **kwargs)

    @torch.no_grad()
    def first_step(self):
        grad_norm = self._grad_norm()
        scale = self.defaults["rho"] / (grad_norm + 1e-12)
        for p in self.param_groups[0]["params"]:
            if p.grad is None: continue
            e_w = p.grad * scale.to(p.device)
            p.add_(e_w)
            self.state[p]["e_w"] = e_w

    @torch.no_grad()
    def second_step(self):
        for p in self.param_groups[0]["params"]:
            if p.grad is None: continue
            p.sub_(self.state[p]["e_w"])
        self.base_optimizer.step()

    def zero_grad(self):
        self.base_optimizer.zero_grad()

    def _grad_norm(self):
        device = self.param_groups[0]["params"][0].device
        norm = torch.norm(
            torch.stack([
                p.grad.norm(2).to(device)
                for p in self.param_groups[0]["params"]
                if p.grad is not None
            ])
        )
        return norm

# %%
class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, padding=1):
        super().__init__()

        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size=kernel_size, padding=padding, groups=in_channels, bias=False)
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.pointwise = nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = F.relu(self.bn1(self.depthwise(x)))
        x = F.relu(self.bn2(self.pointwise(x)))
        return x

class SEBlock(nn.Module):
    def __init__(self, channels, reduction=16):
        super().__init__()

        hidden_dim = max(channels // reduction, 4)
        self.se = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(channels, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, channels),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        b, c, _, _ = x.size()
        weight = self.se(x).view(b, c, 1, 1)
        return x * weight

class DSSEBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.conv = nn.Sequential(
            DepthwiseSeparableConv(channels, channels, kernel_size=3, padding=1),
            DepthwiseSeparableConv(channels, channels, kernel_size=3, padding=1),
            SEBlock(channels)
        )
    def forward(self, x):
        return x + self.conv(x)

class DSResidualSENet(nn.Module):
    def __init__(self, num_classes=43):
        super().__init__()
        self.features = nn.Sequential(
            DepthwiseSeparableConv(3, 32, kernel_size=3, padding=1),
            nn.MaxPool2d(2),
            DepthwiseSeparableConv(32, 64, kernel_size=3, padding=1),
            nn.MaxPool2d(2),
            DSSEBlock(64),
            DepthwiseSeparableConv(64, 128, kernel_size=3, padding=1),
            nn.MaxPool2d(2),
            DSSEBlock(128),
            DepthwiseSeparableConv(128, 256, kernel_size=3, padding=1),
            nn.MaxPool2d(2),
            DSSEBlock(256)
        )

        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )
        
    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
def create_sampler(dataset):
    targets = [label for _, label in dataset.samples]
    class_counts = np.bincount(targets)
    class_weights = 1.0 / class_counts
    sample_weights = [class_weights[label] for label in targets]
    sample_weights = torch.DoubleTensor(sample_weights)
    sampler = WeightedRandomSampler(weights=sample_weights, num_samples=len(sample_weights), replacement=True)
    return sampler

transform_train_48 = transforms.Compose([
    transforms.Resize((48, 48)),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
])

transform_test_48 = transforms.Compose([
    transforms.Resize((48, 48)),
    transforms.ToTensor(),
])

train_dataset = GTSRBDataset(train_path, transform_train_48)
test_dataset = GTSRBDataset(test_path, transform_test_48, is_train=False)

train_sampler = create_sampler(train_dataset)

train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

model = DSResidualSENet()
base_optimizer = optim.Adam
optimizer = SAM(model.parameters(), base_optimizer, lr=0.001)
history = train_model(model, train_loader, test_loader, nn.CrossEntropyLoss(), optimizer, 10, "DSResidualSENet_W")
# Out:
# Epoch 1 | Loss: 2.1189 | Acc: 37.73% | Val Acc: 58.47%
# Epoch 2 | Loss: 0.6064 | Acc: 80.42% | Val Acc: 78.84%
# Epoch 3 | Loss: 0.2910 | Acc: 90.81% | Val Acc: 86.72%
# Epoch 4 | Loss: 0.1807 | Acc: 94.44% | Val Acc: 90.24%
# Epoch 5 | Loss: 0.1317 | Acc: 96.02% | Val Acc: 92.32%
# Epoch 6 | Loss: 0.1045 | Acc: 96.82% | Val Acc: 93.95%
# Epoch 7 | Loss: 0.0876 | Acc: 97.32% | Val Acc: 93.78%
# Epoch 8 | Loss: 0.0732 | Acc: 97.84% | Val Acc: 94.81%
# Epoch 9 | Loss: 0.0630 | Acc: 98.09% | Val Acc: 95.45%
# Epoch 10 | Loss: 0.0532 | Acc: 98.47% | Val Acc: 96.10%

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history['accuracy'], label='Train Acc')
plt.plot(history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history['loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
print_parameters(model, "DSResidualSENet")
evaluate_model(model, test_loader, "DSResidualSENet")
# Out:
# ==================== [DSResidualSENet Layer Details] ====================
# Layer Name                               | Shape                     | Parameters
# -------------------------------------------------------------------------------------
# features.0.depthwise.weight              | [3, 1, 3, 3]              |              27
# features.0.bn1.weight                    | [3]                       |               3
# features.0.bn1.bias                      | [3]                       |               3
# features.0.pointwise.weight              | [32, 3, 1, 1]             |              96
# features.0.bn2.weight                    | [32]                      |              32
# features.0.bn2.bias                      | [32]                      |              32
# features.2.depthwise.weight              | [32, 1, 3, 3]             |             288
# features.2.bn1.weight                    | [32]                      |              32
# features.2.bn1.bias                      | [32]                      |              32
# features.2.pointwise.weight              | [64, 32, 1, 1]            |           2,048
# features.2.bn2.weight                    | [64]                      |              64
# features.2.bn2.bias                      | [64]                      |              64
# features.4.conv.0.depthwise.weight       | [64, 1, 3, 3]             |             576
# features.4.conv.0.bn1.weight             | [64]                      |              64
# features.4.conv.0.bn1.bias               | [64]                      |              64
# features.4.conv.0.pointwise.weight       | [64, 64, 1, 1]            |           4,096
# features.4.conv.0.bn2.weight             | [64]                      |              64
# features.4.conv.0.bn2.bias               | [64]                      |              64
# features.4.conv.1.depthwise.weight       | [64, 1, 3, 3]             |             576
# features.4.conv.1.bn1.weight             | [64]                      |              64
# features.4.conv.1.bn1.bias               | [64]                      |              64
# features.4.conv.1.pointwise.weight       | [64, 64, 1, 1]            |           4,096
# features.4.conv.1.bn2.weight             | [64]                      |              64
# features.4.conv.1.bn2.bias               | [64]                      |              64
# features.4.conv.2.se.2.weight            | [4, 64]                   |             256
# features.4.conv.2.se.2.bias              | [4]                       |               4
# features.4.conv.2.se.4.weight            | [64, 4]                   |             256
# features.4.conv.2.se.4.bias              | [64]                      |              64
# features.5.depthwise.weight              | [64, 1, 3, 3]             |             576
# features.5.bn1.weight                    | [64]                      |              64
# features.5.bn1.bias                      | [64]                      |              64
# features.5.pointwise.weight              | [128, 64, 1, 1]           |           8,192
# features.5.bn2.weight                    | [128]                     |             128
# features.5.bn2.bias                      | [128]                     |             128
# features.7.conv.0.depthwise.weight       | [128, 1, 3, 3]            |           1,152
# features.7.conv.0.bn1.weight             | [128]                     |             128
# features.7.conv.0.bn1.bias               | [128]                     |             128
# features.7.conv.0.pointwise.weight       | [128, 128, 1, 1]          |          16,384
# features.7.conv.0.bn2.weight             | [128]                     |             128
# features.7.conv.0.bn2.bias               | [128]                     |             128
# features.7.conv.1.depthwise.weight       | [128, 1, 3, 3]            |           1,152
# features.7.conv.1.bn1.weight             | [128]                     |             128
# features.7.conv.1.bn1.bias               | [128]                     |             128
# features.7.conv.1.pointwise.weight       | [128, 128, 1, 1]          |          16,384
# features.7.conv.1.bn2.weight             | [128]                     |             128
# features.7.conv.1.bn2.bias               | [128]                     |             128
# features.7.conv.2.se.2.weight            | [8, 128]                  |           1,024
# features.7.conv.2.se.2.bias              | [8]                       |               8
# features.7.conv.2.se.4.weight            | [128, 8]                  |           1,024
# features.7.conv.2.se.4.bias              | [128]                     |             128
# features.8.depthwise.weight              | [128, 1, 3, 3]            |           1,152
# features.8.bn1.weight                    | [128]                     |             128
# features.8.bn1.bias                      | [128]                     |             128
# features.8.pointwise.weight              | [256, 128, 1, 1]          |          32,768
# features.8.bn2.weight                    | [256]                     |             256
# features.8.bn2.bias                      | [256]                     |             256
# features.10.conv.0.depthwise.weight      | [256, 1, 3, 3]            |           2,304
# features.10.conv.0.bn1.weight            | [256]                     |             256
# features.10.conv.0.bn1.bias              | [256]                     |             256
# features.10.conv.0.pointwise.weight      | [256, 256, 1, 1]          |          65,536
# features.10.conv.0.bn2.weight            | [256]                     |             256
# features.10.conv.0.bn2.bias              | [256]                     |             256
# features.10.conv.1.depthwise.weight      | [256, 1, 3, 3]            |           2,304
# features.10.conv.1.bn1.weight            | [256]                     |             256
# features.10.conv.1.bn1.bias              | [256]                     |             256
# features.10.conv.1.pointwise.weight      | [256, 256, 1, 1]          |          65,536
# features.10.conv.1.bn2.weight            | [256]                     |             256
# features.10.conv.1.bn2.bias              | [256]                     |             256
# features.10.conv.2.se.2.weight           | [16, 256]                 |           4,096
# features.10.conv.2.se.2.bias             | [16]                      |              16
# features.10.conv.2.se.4.weight           | [256, 16]                 |           4,096
# features.10.conv.2.se.4.bias             | [256]                     |             256
# classifier.3.weight                      | [43, 256]                 |          11,008
# classifier.3.bias                        | [43]                      |              43
# -------------------------------------------------------------------------------------
# TOTAL TRAINABLE PARAMETERS                                           |         252,520
# =====================================================================================
# --- Evaluating DSResidualSENet ---
# Total Images: 12630
# Correct: 12137
# Accuracy: 96.10%
# 96.09659540775931
